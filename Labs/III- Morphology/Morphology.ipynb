# %% [markdown]
# ## III-Binary images, morphology

# %% [markdown]
# **Objectives:**
# * Learn how to choose a threshold to convert gray_scale images to binary images
# * Learn and visualize the effect of logic operations on binary images.
# * Apply logic operations on binary images.
# * Calculate and plot the translation, difference and reflection of binary images.
# * Use the morphological operations to open or close areas in a binary image.

# %%
# import all packages that will be used in Assignment III
import cv2
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %% [markdown]
# ### Assignment III.1: Binary images

# %% [markdown]
# In this assignment, we will read gray_scale images and convert them to binary. We will learn some techniques to choose the threshold needed in the conversion. We will learn when and how to use dilation and erosion.

# %% [markdown]
# #### A.

# %% [markdown]
# Read the image file 'data/robin_bird.png' and convert it to gray_scale.

# %% [markdown]
# **Answer:**

# %%
bird = cv2.imread('data/robin_bird.png',cv2.IMREAD_COLOR)
bird_rgb = cv2.cvtColor(bird, cv2.COLOR_BGR2RGB)
bird_gray = cv2.cvtColor(bird, cv2.COLOR_BGR2GRAY)
show(bird_rgb)
show(bird_gray)

# %% [markdown]
# #### B.

# %% [markdown]
# Convert the gray_scale image to a binary image using the command **cv2.threshold(im,threshold,maxvalue,cv2.THRESH_BINARY_INV)**, set the threshold as 127 and save the result in **binary_im** variable.

# %% [markdown]
# *Hint:* There are two outputs of **cv2.threshold()**.

# %% [markdown]
# **Answer:**

# %%
binary_im = cv2.threshold(bird_gray, 127, 255, cv2.THRESH_BINARY_INV)
def show(image):
    plt.figure(figsize=(15,9))
    plt.imshow(image,  cmap='gray')
    plt.show()
show(binary_im[1])
binary
# Out:
# (127.0, array([[255, 255, 255, ...,   0,   0,   0],
#        [255, 255, 255, ...,   0,   0,   0],
#        [255, 255, 255, ...,   0,   0,   0],
#        ...,
#        [255, 255, 255, ...,   0,   0,   0],
#        [255, 255, 255, ...,   0,   0,   0],
#        [255, 255, 255, ..., 255,   0,   0]], dtype=uint8))

# %% [markdown]
# Try different values for threshold. Explain the use of threshold parameter in converting from gray_scale to binary?

# %% [markdown]
# **Answer:**

# %%
binary_im = cv2.threshold(bird_gray, 140, 2515, cv2.THRESH_BINARY_INV)
def show(image):
    plt.figure(figsize=(15,9))
    plt.imshow(image)
    plt.show()
show(binary_im[1])
binary_im[1].shape
# Out:
# (168, 300)

# %% [markdown]
# #### C.

# %% [markdown]
# Now we are trying to just have the bird in the image and remove all the other details using morphological operations. It is possible to do that in Python in two steps:
# 1. Define your structuring element by the command, **kernel = np.ones((x,30))**;
# 2. Apply the needed operation using the suitable command (**cv2.erode(img, kernel,iterations)**, **cv2.dilate(img,kernel,iterations)**,**cv2.morphologyEx(img,cv2.MORPH_OPEN,kernel)** and **cv2.morphologyEx(img,v2.MORPH_CLOSE,kernel)**).
# Find the suitable structing elements/s to use, and the combination of morphological operations that will give the needed output.

# %% [markdown]
# **Answer:**

# %%
kernel = np.ones((x,30))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-3aa94c2e25ec> in <module>
# ----> 1 kernel = np.ones((x,30))
#
# NameError: name 'x' is not defined

# %% [markdown]
# Explain your solution.

# %% [markdown]
# **Answer:**
